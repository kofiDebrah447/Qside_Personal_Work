# %%
from faker import Faker

fake = Faker()

# %%
race = [fake.random_element(elements=('White', 'Black', 'Asian', 'Hispanic')) for _ in range(5000)]
use_of_force = [fake.random_element(elements=('Yes', 'No')) for _ in range(5000)]
gender = [fake.random_element(elements=('Male', 'Female')) for _ in range(5000)]
typeofarrest = [fake.random_element(elements=('Taken Into Custody', 'Summoned/Cited', 'Not listed')) for _ in range(5000)]
bondamount = [fake.random_number(digits=5) for _ in range(5000)]
patrol = [fake.random_element(elements=('D1', 'D2', 'D3')) for _ in range(5000)]
officer = [fake.name() for _ in range(5000)]
datetimeofarrest = [fake.date_time_between(start_date='-3y', end_date='now') for _ in range(5000)]
charge1 = [fake.sentence() for _ in range(5000)]
charge2 = [fake.sentence() for _ in range(5000)]
charge3 = [fake.sentence() for _ in range(5000)]
charge4 = [fake.sentence() for _ in range(5000)]
charge5 = [fake.sentence() for _ in range(5000)]
charge6 = [fake.sentence() for _ in range(5000)]

# %%
import pandas as pd

data = {
    'race': race,
    'use_of_force': use_of_force,
    'gender': gender,
    'typeofarrest': typeofarrest,
    'bondamount': bondamount,
    'patrol': patrol,
    'officer': officer,
    'datetimeofarrest': datetimeofarrest,
    'charge1': charge1,
    'charge2': charge2,
    'charge3': charge3,
    'charge4': charge4,
    'charge5': charge5,
    'charge6': charge6
}

df = pd.DataFrame(data)

df.to_csv('fake_data.csv', index=False)

# %%
df
# Out:
#           race use_of_force  gender        typeofarrest  bondamount patrol  \
# 0        Asian           No    Male      Summoned/Cited       98792     D2
# 1        Black          Yes    Male      Summoned/Cited       53031     D2
# 2        Asian          Yes    Male      Summoned/Cited       80939     D1
# 3        Asian          Yes  Female          Not listed       83569     D3
# 4        White           No  Female          Not listed       55168     D2
# ...        ...          ...     ...                 ...         ...    ...
# 4995     Black           No  Female          Not listed       81220     D3
# 4996     Black          Yes  Female      Summoned/Cited       89320     D3
# 4997     Asian          Yes  Female          Not listed       54505     D3
# 4998  Hispanic          Yes    Male          Not listed       14094     D3
# 4999     Black          Yes  Female  Taken Into Custody       30440     D1
#
#              officer           datetimeofarrest  \
# 0          Adrian Yu 2022-03-01 07:29:08.819077
# 1      Amy Mcfarland 2021-06-09 19:36:40.049131
# 2        Tracy Moody 2023-07-05 15:08:45.230052
# 3      Robert Carter 2022-08-07 18:23:23.011153
# 4     Latoya Clayton 2021-11-16 09:23:12.468782
# ...              ...                        ...
# 4995  Elizabeth Hess 2021-03-06 19:36:11.328766
# 4996     Judy Turner 2021-10-18 19:03:47.215183
# 4997    Jessica Hahn 2021-04-04 14:43:38.546452
# 4998      Jacob Cole 2021-11-14 09:11:13.688087
# 4999      Brian Cook 2023-02-17 03:01:09.821055
#
#                                                 charge1  \
# 0     Physical treat although attention participant ...
# 1                      To mother certain spend citizen.
# 2           Particular finally cup former since minute.
# 3                     Choice machine sound thousand Mr.
# 4          Cost international soldier owner successful.
# ...                                                 ...
# 4995                 Baby yourself structure agreement.
# 4996                            Movement or low indeed.
# 4997  Stuff job important environmental prepare comm...
# 4998                 On grow interview think seat hope.
# 4999             Available plant these kitchen culture.
#
#                                                 charge2  \
# 0     Goal claim hard performance wind least respond...
# 1                          Fall decision through truth.
# 2                        Trip behind force leg concern.
# 3     Attack table he little maintain per popular side.
# 4                    Mother edge reality sea education.
# ...                                                 ...
# 4995                                Thus success scene.
# 4996  Bed how carry reason although everybody financ...
# 4997             Newspaper cost use this happen arrive.
# 4998                      Contain toward care ten drop.
# 4999         Bed score phone method his wear education.
#
#                                                 charge3  \
# 0                                   Ready either sound.
# 1     Image bill recently within attack chance weste...
# 2      Want determine culture full rule on fine expect.
# 3                          Idea firm lay rock pull oil.
# 4       Finish beautiful term doctor huge culture must.
# ...                                                 ...
# 4995  Activity suggest fly skill nature what directo...
# 4996                     Right significant adult state.
# 4997                    Field above necessary hope pay.
# 4998                   Trouble none different six body.
# 4999            Late production when cell let much now.
#
#                                                 charge4  \
# 0          Out board through list quality organization.
# 1     Hour reflect everything else sense check condi...
# 2                      Prove give against herself wait.
# 3     Capital candidate somebody probably receive in...
# 4                                     Cut nice section.
# ...                                                 ...
# 4995                    Television too executive about.
# 4996  Require relationship age management pretty els...
# 4997                                    Send worker do.
# 4998                            Gas heart be sometimes.
# 4999             All be religious material camera fill.
#
#                                               charge5  \
# 0                       Treat visit fast choose here.
# 1                 Garden town bank democratic wonder.
# 2           Her ten no maybe well human arrive child.
# 3                                    Six truth prove.
# 4                      Report represent thought beat.
# ...                                               ...
# 4995                   Safe assume region drive tree.
# 4996  Listen increase factor culture economic likely.
# 4997            Section also claim possible majority.
# 4998                     Know growth although rather.
# 4999                     Like maybe condition former.
#
#                                                 charge6
# 0                      Probably stay catch member very.
# 1                               Shoulder stock know at.
# 2                     Effect defense trade great cover.
# 3                            Day them book begin price.
# 4                 Team very focus identify environment.
# ...                                                 ...
# 4995                           Spring have pressure up.
# 4996  Structure necessary hand job mean herself prob...
# 4997                                 Wish last provide.
# 4998                          Able before also however.
# 4999  All certain list treatment physical hotel kitc...
#
# [5000 rows x 14 columns]
