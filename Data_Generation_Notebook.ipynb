# %%
from faker import Faker

fake = Faker()

# %%
import random

possible_charges = [
    "Theft",
    "Assault",
    "Burglary",
    "Robbery",
    "Drug Possession",
    "Driving Under the Influence (DUI)",
    "Domestic Violence",
    "Fraud",
    "Forgery",
    "Arson",
    "Nan"
]

# %%
race = [fake.random_element(elements=('White', 'Black', 'Asian', 'Hispanic')) for _ in range(5000)]
use_of_force = [fake.random_element(elements=('Yes', 'No')) for _ in range(5000)]
gender = [fake.random_element(elements=('Male', 'Female')) for _ in range(5000)]
typeofarrest = [fake.random_element(elements=('Taken Into Custody', 'Summoned/Cited', 'Not listed')) for _ in range(5000)]
bondamount = [fake.random_number(digits=5) for _ in range(5000)]
patrol = [fake.random_element(elements=('D1', 'D2', 'D3')) for _ in range(5000)]
officer = [fake.name() for _ in range(5000)]
datetimeofarrest = [fake.date_time_between(start_date='-3y', end_date='now') for _ in range(5000)]
searchconducted = [fake.random_element(elements=('Yes', 'No')) for _ in range(5000)]
charge1 = [random.choice(possible_charges) for _ in range(5000)]
charge2 = [random.choice(possible_charges) for _ in range(5000)]
charge3 = [random.choice(possible_charges) for _ in range(5000)]
charge4 = [random.choice(possible_charges) for _ in range(5000)]
charge5 = [random.choice(possible_charges) for _ in range(5000)]
charge6 = [random.choice(possible_charges) for _ in range(5000)]

# %%
import pandas as pd

data = {
    'race': race,
    'use_of_force': use_of_force,
    'gender': gender,
    'typeofarrest': typeofarrest,
    'bondamount': bondamount,
    'patrol': patrol,
    'officer': officer,
    'datetimeofarrest': datetimeofarrest,
    'searchconducted': searchconducted,
    'charge1': charge1,
    'charge2': charge2,
    'charge3': charge3,
    'charge4': charge4,
    'charge5': charge5,
    'charge6': charge6
}

df = pd.DataFrame(data)

df.to_csv('Frankenmuth.csv', index=False)

# %%
df
# Out:
#           race use_of_force  gender        typeofarrest  bondamount patrol  \
# 0        White          Yes    Male  Taken Into Custody       66451     D2
# 1     Hispanic          Yes    Male          Not listed       87564     D2
# 2     Hispanic          Yes    Male  Taken Into Custody       76467     D2
# 3        Asian          Yes  Female          Not listed       28828     D1
# 4        Asian           No  Female          Not listed       71110     D2
# ...        ...          ...     ...                 ...         ...    ...
# 4995  Hispanic           No    Male      Summoned/Cited       36679     D1
# 4996     White          Yes    Male  Taken Into Custody       44820     D3
# 4997  Hispanic           No  Female      Summoned/Cited       85927     D1
# 4998     White           No    Male          Not listed       31708     D2
# 4999     Asian           No  Female  Taken Into Custody        9413     D2
#
#                officer    datetimeofarrest searchconducted  \
# 0         Andrea Baker 2023-05-08 21:59:20             Yes
# 1          Joy Roberts 2023-08-11 19:28:45              No
# 2     Sandra Schroeder 2022-06-14 23:40:31              No
# 3         Tara Kennedy 2022-08-02 13:54:21              No
# 4        Kevin Hancock 2023-11-27 15:43:35             Yes
# ...                ...                 ...             ...
# 4995  Amanda Wells DDS 2024-02-07 13:17:18             Yes
# 4996     James Schmidt 2021-12-05 23:57:16              No
# 4997    Jennifer Combs 2021-05-07 19:15:32             Yes
# 4998       Tracy Smith 2021-06-18 12:57:12             Yes
# 4999        Ryan Leach 2021-05-13 06:30:00              No
#
#                                 charge1          charge2          charge3  \
# 0                                   Nan          Forgery            Fraud
# 1                              Burglary  Drug Possession          Assault
# 2                               Forgery  Drug Possession  Drug Possession
# 3     Driving Under the Influence (DUI)          Assault              Nan
# 4                                 Arson              Nan          Robbery
# ...                                 ...              ...              ...
# 4995                              Fraud          Forgery            Arson
# 4996                    Drug Possession          Assault          Assault
# 4997                            Assault          Assault          Robbery
# 4998                              Theft          Assault            Fraud
# 4999                            Forgery         Burglary          Assault
#
#                                 charge4                            charge5  \
# 0                                 Theft                    Drug Possession
# 1                     Domestic Violence                           Burglary
# 2                                 Fraud  Driving Under the Influence (DUI)
# 3     Driving Under the Influence (DUI)                  Domestic Violence
# 4                                 Fraud                            Assault
# ...                                 ...                                ...
# 4995                  Domestic Violence                            Assault
# 4996                  Domestic Violence                              Fraud
# 4997                              Arson                  Domestic Violence
# 4998                  Domestic Violence                            Robbery
# 4999                                Nan                            Forgery
#
#                                 charge6
# 0                                   Nan
# 1     Driving Under the Influence (DUI)
# 2                     Domestic Violence
# 3     Driving Under the Influence (DUI)
# 4                                   Nan
# ...                                 ...
# 4995                    Drug Possession
# 4996                              Arson
# 4997                              Fraud
# 4998                              Fraud
# 4999                            Robbery
#
# [5000 rows x 15 columns]
